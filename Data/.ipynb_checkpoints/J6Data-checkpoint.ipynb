# %% [markdown]
# ---
# title: J6 Test Data
#
# ---
# ## Data from J6 Lateral (ours)
#
# ### Weir Locations
#
# Weir 1: ///ample.misconduct/eggshell 2.625"
# Weir 2: ///combustion.educations.jetting 1.625"
# Weir 3: ///theoretical.sharper.things 1.625"

# %%
2+3
# Out:
# 5
